# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pyreadstat
import statsmodels.api as sm

from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.stats.stattools import durbin_watson
from statsmodels.stats.diagnostic import het_breuschpagan
from scipy import stats
from statsmodels.stats.diagnostic import het_white



# import statsmodels.formula.api as sms

pd.set_option('display.max_columns', None)  # Отображать все колонки

# %%
df, meta = pyreadstat.read_sav('data2021.sav')
# df = pd.read_stata('r29i_os_73.dta', convert_categoricals=False)

# %%
# df = df.dropna(axis=1)
df = df.drop_duplicates()

# %%
# print("Размерность датафрейма:")
# print(df.shape)
# print()
# missing_values_count = df.isna().sum()  # Общее количество пропущенных значений
# missing_values_percentage = (df.isna().mean() * 100).round(2)  # Процент пропущенных значений
# unique_values_count = df.nunique()  # Количество уникальных значений в каждом столбце

# missing_summary = pd.DataFrame({
#     'Missing Values Count': missing_values_count,
#     'Missing Values Percentage': missing_values_percentage,
#     'Unique Values Count': unique_values_count
# })

# print("Сводка по отсутствующим значениям и уникальным значениям:")
# display(missing_summary)

# %%
df = df[(df['region'] == 137) | (df['region'] == 141)].copy()

# %%
# df[['zj125.6', 'zj721631', 'zj721632', 'zj721635', 'zj72.171', 'zj73', 'zj77', 'zj87', 'zj90', 'zj200']]
# filtered_columns = [col for col in df.columns if 'j72.171' in col]
# filtered_columns
 # 'zj72.171', 'zj73', 'zj77', 'zj87', 'zj90' -- Нашлись

# %%
# df['zh6'].value_counts()

# %%
filtered_columns = [col for col in df.columns if '1.1' in col]
print(filtered_columns)
# Out:
# ['zj1.1.1', 'zj1.1.2', 'zj1.1.3', 'zj1.1.4', 'zj11.1', 'zj41.1', 'zj401.1a', 'zj131.1', 'zj81.1', 'zn1.1', 'zn31.1', 'zs1.1', 'zk761.1a', 'zk761.1b', 'zk761.1c']

# %%
# df['zj10'].isna().sum()

# %%
# # Инициализируем пустой список для хранения реальных имен колонок
# selected_columns = []

# # Проходим по каждой подстроке и ищем соответствующие колонки
# for substr in substrings:
#     # Ищем соответствующие колонки (учитывая регистр)
#     matching_cols = [col for col in df.columns if substr in col]
#     # Если колонки не найдены, пробуем поиск без учета регистра
#     if not matching_cols:
#         matching_cols = [col for col in df.columns if substr.lower() in col.lower()]
#     # Добавляем найденные колонки в список
#     if matching_cols:
#         selected_columns.extend(matching_cols)
#     else:
#         print(f"Колонки для подстроки '{substr}' не найдены")

# # Удаляем возможные дубликаты
# selected_columns = list(set(selected_columns))

# # Теперь отфильтруем ваш датафрейм по этим колонкам
# df_filtered = df[selected_columns].copy()

# %%
# df[['zj13.2']]

# %%
l = [
    'H5', 'H6', 'AGE', 'EDUC', 'DIPLOM', 'MARST', 'OCCUP08',  
    'J6', 'J6.1', 'J6.2', 'J8', 'STATUS', 'J4.1', 'J10', 'J11.1', 'J14', 'J21A', 'J23', 'J29',
'J32.1', 'J35.1', 'J72.5', 'J260'
# 'zj161.3y', 'zj161.3m'
]

# significant_features2 = [
#     "J72.17",  # Семейное положение
#     "J322",  # Состоит ли в зарегистрированном браке
#     "J77",  # Наличие работы у респондента
#     "J78",  # Опыт работы
#     "J79",  # Общий трудовой стаж
# ]

# %%
# filtered_columns = [col for col in df.columns if 'j8' in col]
# print(filtered_columns)
itog_list = ['zj13.2', 'zj9', 'zh5', 'zh6', 'z_age', 'z_educ', 'z_diplom', 'z_marst', 'z_occup08', 'zj6', 'zj6.1a', 'zj6.2', 'zj8', 'status', 'zj4.1',
'zj10', 'zj11.1', 'zj14', 'zj21a', 'zj23', 'zj29', 'zj32.1', 'zj35.1', 'zj69.9c', 'zj75', 'zj260', 'zl2.2', 'region', 
            
'zj72.171', 'zj73', 'zj77', 'zj87', 'zj90',
            
            'zj161.3y', 'zj1.1.1']
# zi4

# %%
filtered_columns = [col for col in df.columns if '72.172' in col]
print(filtered_columns)
# Out:
# ['zj72.172']

# %%
len(itog_list)
# Out:
# 35

# %%
df = df[itog_list].copy()

# %%
# df['zj161.3m'].value_counts()

# %%
print("Размерность датафрейма:")
print(df.shape)
print()
missing_values_count = df.isna().sum()  # Общее количество пропущенных значений
missing_values_percentage = (df.isna().mean() * 100).round(2)  # Процент пропущенных значений
unique_values_count = df.nunique()  # Количество уникальных значений в каждом столбце

missing_summary = pd.DataFrame({
    'Missing Values Count': missing_values_count,
    'Missing Values Percentage': missing_values_percentage,
    'Unique Values Count': unique_values_count
})

print("Сводка по отсутствующим значениям и уникальным значениям:")
display(missing_summary)
# Out:
# Размерность датафрейма:
# (790, 35)
#
# Сводка по отсутствующим значениям и уникальным значениям:
#            Missing Values Count  Missing Values Percentage  \
# zj13.2                      425                      53.80
# zj9                         388                      49.11
# zh5                           0                       0.00
# zh6                           0                       0.00
# z_age                         0                       0.00
# z_educ                      119                      15.06
# z_diplom                    119                      15.06
# z_marst                     119                      15.06
# z_occup08                   388                      49.11
# zj6                         388                      49.11
# zj6.1a                      388                      49.11
# zj6.2                       388                      49.11
# zj8                         404                      51.14
# status                        0                       0.00
# zj4.1                       388                      49.11
# zj10                        398                      50.38
# zj11.1                      425                      53.80
# zj14                        425                      53.80
# zj21a                       425                      53.80
# zj23                        425                      53.80
# zj29                        425                      53.80
# zj32.1                      397                      50.25
# zj35.1                      779                      98.61
# zj69.9c                       0                       0.00
# zj75                        566                      71.65
# zj260                       119                      15.06
# zl2.2                       119                      15.06
# region                        0                       0.00
# zj72.171                    119                      15.06
# zj73                        119                      15.06
# zj77                        119                      15.06
# zj87                        786                      99.49
# zj90                        119                      15.06
# zj161.3y                    171                      21.65
# zj1.1.1                     388                      49.11
#
#            Unique Values Count
# zj13.2                      65
# zj9                          2
# zh5                          2
# zh6                         91
# z_age                      176
# z_educ                      20
# z_diplom                     7
# z_marst                      8
# z_occup08                    9
# zj6                          2
# zj6.1a                      13
# zj6.2                       34
# zj8                         78
# status                       2
# zj4.1                       27
# zj10                        97
# zj11.1                       4
# zj14                         3
# zj21a                        3
# zj23                         4
# zj29                         4
# zj32.1                       3
# zj35.1                       5
# zj69.9c                     91
# zj75                         2
# zj260                        4
# zl2.2                        3
# region                       2
# zj72.171                     3
# zj73                         2
# zj77                         2
# zj87                         2
# zj90                        13
# zj161.3y                    60
# zj1.1.1                      7

# %%
df_filter = df.loc[:, df.isna().mean() < 0.6] # Оставляю те колонки где меньше 60 процентов пропусков

# %%
print("Размерность датафрейма:")
print(df_filter.shape)
print()
missing_values_count = df_filter.isna().sum()  # Общее количество пропущенных значений
missing_values_percentage = (df_filter.isna().mean() * 100).round(2)  # Процент пропущенных значений
unique_values_count = df_filter.nunique()  # Количество уникальных значений в каждом столбце

missing_summary = pd.DataFrame({
    'Missing Values Count': missing_values_count,
    'Missing Values Percentage': missing_values_percentage,
    'Unique Values Count': unique_values_count
})

print("Сводка по отсутствующим значениям и уникальным значениям:")
display(missing_summary)
# Out:
# Размерность датафрейма:
# (790, 32)
#
# Сводка по отсутствующим значениям и уникальным значениям:
#            Missing Values Count  Missing Values Percentage  \
# zj13.2                      425                      53.80
# zj9                         388                      49.11
# zh5                           0                       0.00
# zh6                           0                       0.00
# z_age                         0                       0.00
# z_educ                      119                      15.06
# z_diplom                    119                      15.06
# z_marst                     119                      15.06
# z_occup08                   388                      49.11
# zj6                         388                      49.11
# zj6.1a                      388                      49.11
# zj6.2                       388                      49.11
# zj8                         404                      51.14
# status                        0                       0.00
# zj4.1                       388                      49.11
# zj10                        398                      50.38
# zj11.1                      425                      53.80
# zj14                        425                      53.80
# zj21a                       425                      53.80
# zj23                        425                      53.80
# zj29                        425                      53.80
# zj32.1                      397                      50.25
# zj69.9c                       0                       0.00
# zj260                       119                      15.06
# zl2.2                       119                      15.06
# region                        0                       0.00
# zj72.171                    119                      15.06
# zj73                        119                      15.06
# zj77                        119                      15.06
# zj90                        119                      15.06
# zj161.3y                    171                      21.65
# zj1.1.1                     388                      49.11
#
#            Unique Values Count
# zj13.2                      65
# zj9                          2
# zh5                          2
# zh6                         91
# z_age                      176
# z_educ                      20
# z_diplom                     7
# z_marst                      8
# z_occup08                    9
# zj6                          2
# zj6.1a                      13
# zj6.2                       34
# zj8                         78
# status                       2
# zj4.1                       27
# zj10                        97
# zj11.1                       4
# zj14                         3
# zj21a                        3
# zj23                         4
# zj29                         4
# zj32.1                       3
# zj69.9c                     91
# zj260                        4
# zl2.2                        3
# region                       2
# zj72.171                     3
# zj73                         2
# zj77                         2
# zj90                        13
# zj161.3y                    60
# zj1.1.1                      7

# %%
# ПОТЕНЦИАЛЬНЫЕ ЦЕЛЕВЫЕ ПЕРЕМЕННЫЕ:
# 'zj13.2'	
# 'zj10'

# %%
 # Больше чем сколько колонок должно быть отсутствующие значения в строках? 
# col = df_filter[df_filter.isna().sum(axis=1) > 13].columns
# len(col)

# %%
# df_filter.dropna(thresh=9) # Дропаю строки в которых есть хотя бы 9

# %%
# df_filter[df_filter.isna().sum(axis=1) > 13]

# %%
# df_filter = df_filter.drop('zj13.2', axis=1)

# %%
df_filter['region'].value_counts()
# Out:
# region
# 141.0    425
# 137.0    365
# Name: count, dtype: int64

# %%
df_filter.loc[:, :] = df_filter.where(df_filter <= 99999, np.nan)
# Out:
# C:\Users\MadBoss\AppData\Local\Temp\ipykernel_7152\260474843.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filter.loc[:, :] = df_filter.where(df_filter <= 99999, np.nan)

# %%
# df_filter.loc[df_filter > 9999999] = np.nan
print("Размерность датафрейма:")
print(df_filter.shape)
print()
missing_values_count = df_filter.isna().sum()  # Общее количество пропущенных значений
missing_values_percentage = (df_filter.isna().mean() * 100).round(2)  # Процент пропущенных значений
unique_values_count = df_filter.nunique()  # Количество уникальных значений в каждом столбце

missing_summary = pd.DataFrame({
    'Missing Values Count': missing_values_count,
    'Missing Values Percentage': missing_values_percentage,
    'Unique Values Count': unique_values_count
})

print("Сводка по отсутствующим значениям и уникальным значениям:")
display(missing_summary)
# Out:
# Размерность датафрейма:
# (790, 32)
#
# Сводка по отсутствующим значениям и уникальным значениям:
#            Missing Values Count  Missing Values Percentage  \
# zj13.2                      448                      56.71
# zj9                         388                      49.11
# zh5                           0                       0.00
# zh6                           0                       0.00
# z_age                         0                       0.00
# z_educ                      123                      15.57
# z_diplom                    123                      15.57
# z_marst                     122                      15.44
# z_occup08                   388                      49.11
# zj6                         388                      49.11
# zj6.1a                      405                      51.27
# zj6.2                       410                      51.90
# zj8                         428                      54.18
# status                        0                       0.00
# zj4.1                       390                      49.37
# zj10                        415                      52.53
# zj11.1                      430                      54.43
# zj14                        426                      53.92
# zj21a                       426                      53.92
# zj23                        434                      54.94
# zj29                        427                      54.05
# zj32.1                      398                      50.38
# zj69.9c                       0                       0.00
# zj260                       127                      16.08
# zl2.2                       124                      15.70
# region                        0                       0.00
# zj72.171                    120                      15.19
# zj73                        119                      15.06
# zj77                        119                      15.06
# zj90                        119                      15.06
# zj161.3y                    194                      24.56
# zj1.1.1                     398                      50.38
#
#            Unique Values Count
# zj13.2                      56
# zj9                          2
# zh5                          2
# zh6                         91
# z_age                      176
# z_educ                      19
# z_diplom                     6
# z_marst                      6
# z_occup08                    9
# zj6                          2
# zj6.1a                      12
# zj6.2                       33
# zj8                         76
# status                       2
# zj4.1                       26
# zj10                        87
# zj11.1                       2
# zj14                         2
# zj21a                        2
# zj23                         2
# zj29                         2
# zj32.1                       2
# zj69.9c                     91
# zj260                        2
# zl2.2                        2
# region                       2
# zj72.171                     2
# zj73                         2
# zj77                         2
# zj90                        13
# zj161.3y                    57
# zj1.1.1                      5

# %%
df_filter = df_filter.drop('zj13.2', axis=1)
# Дропаю эту колонку тк в ней больше nan чем в zj10

# %%
df = df_filter.copy()
df
# Out:
#        zj9  zh5     zh6  z_age  z_educ  z_diplom  z_marst  z_occup08  zj6  \
# 1149   NaN  2.0  1947.0   74.5    18.0       5.0      2.0        NaN  NaN
# 1150   NaN  1.0  1938.0   83.0    14.0       4.0      2.0        NaN  NaN
# 1151   NaN  2.0  1940.0   81.5     7.0       2.0      5.0        NaN  NaN
# 1152   1.0  2.0  1968.0   52.5    16.0       4.0      2.0        8.0  2.0
# 1153   1.0  1.0  1962.0   58.5    18.0       5.0      2.0        7.0  2.0
# ...    ...  ...     ...    ...     ...       ...      ...        ...  ...
# 11821  NaN  2.0  1955.0   66.5     8.0       2.0      5.0        NaN  NaN
# 11822  NaN  1.0  2021.0    0.0     NaN       NaN      NaN        NaN  NaN
# 11823  NaN  2.0  2021.0    0.0     NaN       NaN      NaN        NaN  NaN
# 11824  1.0  1.0  1968.0   53.5    18.0       5.0      3.0        7.0  2.0
# 11825  NaN  1.0  2021.0    0.0     NaN       NaN      NaN        NaN  NaN
#
#        zj6.1a  zj6.2    zj8  status  zj4.1     zj10  zj11.1  zj14  zj21a  \
# 1149      NaN    NaN    NaN     2.0    NaN      NaN     NaN   NaN    NaN
# 1150      NaN    NaN    NaN     2.0    NaN      NaN     NaN   NaN    NaN
# 1151      NaN    NaN    NaN     2.0    NaN      NaN     NaN   NaN    NaN
# 1152     12.0   48.0  192.0     2.0    1.0  15000.0     1.0   2.0    1.0
# 1153      8.0   40.0  160.0     2.0   14.0  14000.0     1.0   2.0    2.0
# ...       ...    ...    ...     ...    ...      ...     ...   ...    ...
# 11821     NaN    NaN    NaN     1.0    NaN      NaN     NaN   NaN    NaN
# 11822     NaN    NaN    NaN     1.0    NaN      NaN     NaN   NaN    NaN
# 11823     NaN    NaN    NaN     1.0    NaN      NaN     NaN   NaN    NaN
# 11824     6.0   30.0  126.0     1.0   10.0  21800.0     NaN   2.0    2.0
# 11825     NaN    NaN    NaN     1.0    NaN      NaN     NaN   NaN    NaN
#
#        zj23  zj29  zj32.1  zj69.9c  zj260  zl2.2  region  zj72.171  zj73  \
# 1149    NaN   NaN     NaN   1947.0    2.0    2.0   137.0       1.0   1.0
# 1150    NaN   NaN     NaN   1938.0    2.0    2.0   137.0       1.0   1.0
# 1151    NaN   NaN     NaN   1940.0    2.0    2.0   137.0       1.0   1.0
# 1152    2.0   2.0     2.0   1968.0    2.0    2.0   137.0       1.0   2.0
# 1153    2.0   2.0     2.0   1962.0    2.0    2.0   137.0       1.0   2.0
# ...     ...   ...     ...      ...    ...    ...     ...       ...   ...
# 11821   NaN   NaN     NaN   1955.0    2.0    2.0   141.0       1.0   1.0
# 11822   NaN   NaN     NaN   2021.0    NaN    NaN   141.0       NaN   NaN
# 11823   NaN   NaN     NaN   2021.0    NaN    NaN   141.0       NaN   NaN
# 11824   1.0   2.0     2.0   1968.0    2.0    2.0   141.0       2.0   2.0
# 11825   NaN   NaN     NaN   2021.0    NaN    NaN   141.0       NaN   NaN
#
#        zj77  zj90  zj161.3y  zj1.1.1
# 1149    2.0   4.0      31.0      NaN
# 1150    2.0   4.0      48.0      NaN
# 1151    2.0   4.0      38.0      NaN
# 1152    1.0  12.0      31.0      2.0
# 1153    1.0  12.0      38.0      1.0
# ...     ...   ...       ...      ...
# 11821   2.0   4.0      39.0      NaN
# 11822   NaN   NaN       NaN      NaN
# 11823   NaN   NaN       NaN      NaN
# 11824   1.0  12.0      30.0      2.0
# 11825   NaN   NaN       NaN      NaN
#
# [790 rows x 31 columns]

# %%
clear_df = df.dropna(axis=0, how='any')

# %%
clear_df['region'].value_counts()
# Out:
# region
# 137.0    136
# 141.0    133
# Name: count, dtype: int64

# %%
data_dict = {
"zj13.2": "avg_wage_year",
"zj9": "is_income_30_days",
"zh5": "sex",
"zh6": "birth_year",
"z_age": "age",
"z_educ": "education",
"z_diplom": "diplom",
"z_marst": "family",
"z_occup08": "proff_group",
"zj6": "is_ceo",
"zj6.1a": "work_day_hours",
"zj6.2": "work_week_hours",
"zj8": "actual_hours_30d",
"status": "settlement_type",
"zj4.1": "industry",
"zj10": "income_30d",
"zj11.1": "officially_employed",
"zj14": "company_debt",
"zj21a": "paid_leave",
"zj23": "state_owner",
"zj29": "entrepreneur_activity",
"zj32.1": "additional_job",
"zj69.9c": "birth_year2",
"zj260": "foreign_language",
"zl2.2": "additional_health_insurance",
"region": "region",
"zj72.171": "children",
"zj73": "pension",
"zj77": "employment_status",
"zj90": "main_activity",
"zj161.3y": "work_exp",
"zj1.1.1": "job_satisfaction"
}

# %%
df = df.rename(columns=data_dict)
df.head(3)
# Out:
#       is_income_30_days  sex  birth_year   age  education  diplom  family  \
# 1149                NaN  2.0      1947.0  74.5       18.0     5.0     2.0
# 1150                NaN  1.0      1938.0  83.0       14.0     4.0     2.0
# 1151                NaN  2.0      1940.0  81.5        7.0     2.0     5.0
#
#       proff_group  is_ceo  work_day_hours  work_week_hours  actual_hours_30d  \
# 1149          NaN     NaN             NaN              NaN               NaN
# 1150          NaN     NaN             NaN              NaN               NaN
# 1151          NaN     NaN             NaN              NaN               NaN
#
#       settlement_type  industry  income_30d  officially_employed  \
# 1149              2.0       NaN         NaN                  NaN
# 1150              2.0       NaN         NaN                  NaN
# 1151              2.0       NaN         NaN                  NaN
#
#       company_debt  paid_leave  state_owner  entrepreneur_activity  \
# 1149           NaN         NaN          NaN                    NaN
# 1150           NaN         NaN          NaN                    NaN
# 1151           NaN         NaN          NaN                    NaN
#
#       additional_job  birth_year2  foreign_language  \
# 1149             NaN       1947.0               2.0
# 1150             NaN       1938.0               2.0
# 1151             NaN       1940.0               2.0
#
#       additional_health_insurance  region  children  pension  \
# 1149                          2.0   137.0       1.0      1.0
# 1150                          2.0   137.0       1.0      1.0
# 1151                          2.0   137.0       1.0      1.0
#
#       employment_status  main_activity  work_exp  job_satisfaction
# 1149                2.0            4.0      31.0               NaN
# 1150                2.0            4.0      48.0               NaN
# 1151                2.0            4.0      38.0               NaN

# %%
print("Размерность датафрейма:")
print(df.shape)
print()
missing_values_count = df.isna().sum()  # Общее количество пропущенных значений
missing_values_percentage = (df.isna().mean() * 100).round(2)  # Процент пропущенных значений
unique_values_count = df.nunique()  # Количество уникальных значений в каждом столбце

missing_summary = pd.DataFrame({
    'Missing Values Count': missing_values_count,
    'Missing Values Percentage': missing_values_percentage,
    'Unique Values Count': unique_values_count
})

print("Сводка по отсутствующим значениям и уникальным значениям:")
display(missing_summary)
# Out:
# Размерность датафрейма:
# (790, 31)
#
# Сводка по отсутствующим значениям и уникальным значениям:
#                              Missing Values Count  Missing Values Percentage  \
# is_income_30_days                             388                      49.11
# sex                                             0                       0.00
# birth_year                                      0                       0.00
# age                                             0                       0.00
# education                                     123                      15.57
# diplom                                        123                      15.57
# family                                        122                      15.44
# proff_group                                   388                      49.11
# is_ceo                                        388                      49.11
# work_day_hours                                405                      51.27
# work_week_hours                               410                      51.90
# actual_hours_30d                              428                      54.18
# settlement_type                                 0                       0.00
# industry                                      390                      49.37
# income_30d                                    415                      52.53
# officially_employed                           430                      54.43
# company_debt                                  426                      53.92
# paid_leave                                    426                      53.92
# state_owner                                   434                      54.94
# entrepreneur_activity                         427                      54.05
# additional_job                                398                      50.38
# birth_year2                                     0                       0.00
# foreign_language                              127                      16.08
# additional_health_insurance                   124                      15.70
# region                                          0                       0.00
# children                                      120                      15.19
# pension                                       119                      15.06
# employment_status                             119                      15.06
# main_activity                                 119                      15.06
# work_exp                                      194                      24.56
# job_satisfaction                              398                      50.38
#
#                              Unique Values Count
# is_income_30_days                              2
# sex                                            2
# birth_year                                    91
# age                                          176
# education                                     19
# diplom                                         6
# family                                         6
# proff_group                                    9
# is_ceo                                         2
# work_day_hours                                12
# work_week_hours                               33
# actual_hours_30d                              76
# settlement_type                                2
# industry                                      26
# income_30d                                    87
# officially_employed                            2
# company_debt                                   2
# paid_leave                                     2
# state_owner                                    2
# entrepreneur_activity                          2
# additional_job                                 2
# birth_year2                                   91
# foreign_language                               2
# additional_health_insurance                    2
# region                                         2
# children                                       2
# pension                                        2
# employment_status                              2
# main_activity                                 13
# work_exp                                      57
# job_satisfaction                               5

# %%
df = df.dropna(subset=['income_30d'])

# %%
print("Размерность датафрейма:")
print(df.shape)
print()
missing_values_count = df.isna().sum()  # Общее количество пропущенных значений
missing_values_percentage = (df.isna().mean() * 100).round(2)  # Процент пропущенных значений
unique_values_count = df.nunique()  # Количество уникальных значений в каждом столбце

missing_summary = pd.DataFrame({
    'Missing Values Count': missing_values_count,
    'Missing Values Percentage': missing_values_percentage,
    'Unique Values Count': unique_values_count
})

print("Сводка по отсутствующим значениям и уникальным значениям:")
display(missing_summary)
# Out:
# Размерность датафрейма:
# (375, 31)
#
# Сводка по отсутствующим значениям и уникальным значениям:
#                              Missing Values Count  Missing Values Percentage  \
# is_income_30_days                               0                       0.00
# sex                                             0                       0.00
# birth_year                                      0                       0.00
# age                                             0                       0.00
# education                                       2                       0.53
# diplom                                          2                       0.53
# family                                          0                       0.00
# proff_group                                     0                       0.00
# is_ceo                                          0                       0.00
# work_day_hours                                 11                       2.93
# work_week_hours                                14                       3.73
# actual_hours_30d                               34                       9.07
# settlement_type                                 0                       0.00
# industry                                        2                       0.53
# income_30d                                      0                       0.00
# officially_employed                            39                      10.40
# company_debt                                   36                       9.60
# paid_leave                                     36                       9.60
# state_owner                                    44                      11.73
# entrepreneur_activity                          37                       9.87
# additional_job                                 10                       2.67
# birth_year2                                     0                       0.00
# foreign_language                                2                       0.53
# additional_health_insurance                     1                       0.27
# region                                          0                       0.00
# children                                        0                       0.00
# pension                                         0                       0.00
# employment_status                               0                       0.00
# main_activity                                   0                       0.00
# work_exp                                       11                       2.93
# job_satisfaction                                7                       1.87
#
#                              Unique Values Count
# is_income_30_days                              1
# sex                                            2
# birth_year                                    55
# age                                           99
# education                                     13
# diplom                                         5
# family                                         6
# proff_group                                    9
# is_ceo                                         2
# work_day_hours                                11
# work_week_hours                               30
# actual_hours_30d                              72
# settlement_type                                2
# industry                                      26
# income_30d                                    87
# officially_employed                            2
# company_debt                                   2
# paid_leave                                     2
# state_owner                                    2
# entrepreneur_activity                          2
# additional_job                                 2
# birth_year2                                   55
# foreign_language                               2
# additional_health_insurance                    2
# region                                         2
# children                                       2
# pension                                        2
# employment_status                              1
# main_activity                                  6
# work_exp                                      50
# job_satisfaction                               5

# %%
# Не хочу жертвовать 40 строками поэтому буду удалять постепенно колонки менее важные на мой взгляд
# и смотреть сколько nan остается

# actual_hours_30d	
# work_week_hours
# officially_employed	
# company_debt
# paid_leave
# state_owner
# entrepreneur_activity	

# "zj6.2": "work_week_hours", Сколько часов в среднем продолжается Ваша обычная рабочая неделя?
# "zj8": "actual_hours_30d", Сколько часов Вы фактически отработали по основному месту работы в течение последних 30 дней?

# "zj11.1": "officially_employed", Устроен официально или нет
# Очень жалко терять эту колонку, есть идея заполнить нулями все что не является твердым да

# "zj14": "company_debt", Должно ли работнику предприятие какие то деньги? 
# "zj21a": "paid_leave", был ли работник в оплачиваемом отпуске за последний год
# "zj23": "state_owner", # Предприятие государственное?
# "zj29": "entrepreneur_activity", # Как вы считаете, вы занимаетесь предпринимательской деятельностью на этой работе?

# %%
# Пробую дропнуть:
# "zj21a": "paid_leave", был ли работник в оплачиваемом отпуске за последний год

# %%
df = df.drop(
    ['actual_hours_30d', 'work_week_hours', 'officially_employed', 'company_debt', 'paid_leave', 'state_owner', 'entrepreneur_activity'], axis=1
)

# %%
print("Размерность датафрейма:")
print(df.shape)
print()
missing_values_count = df.isna().sum()  # Общее количество пропущенных значений
missing_values_percentage = (df.isna().mean() * 100).round(2)  # Процент пропущенных значений
unique_values_count = df.nunique()  # Количество уникальных значений в каждом столбце

missing_summary = pd.DataFrame({
    'Missing Values Count': missing_values_count,
    'Missing Values Percentage': missing_values_percentage,
    'Unique Values Count': unique_values_count
})

print("Сводка по отсутствующим значениям и уникальным значениям:")
display(missing_summary)
# Out:
# Размерность датафрейма:
# (375, 24)
#
# Сводка по отсутствующим значениям и уникальным значениям:
#                              Missing Values Count  Missing Values Percentage  \
# is_income_30_days                               0                       0.00
# sex                                             0                       0.00
# birth_year                                      0                       0.00
# age                                             0                       0.00
# education                                       2                       0.53
# diplom                                          2                       0.53
# family                                          0                       0.00
# proff_group                                     0                       0.00
# is_ceo                                          0                       0.00
# work_day_hours                                 11                       2.93
# settlement_type                                 0                       0.00
# industry                                        2                       0.53
# income_30d                                      0                       0.00
# additional_job                                 10                       2.67
# birth_year2                                     0                       0.00
# foreign_language                                2                       0.53
# additional_health_insurance                     1                       0.27
# region                                          0                       0.00
# children                                        0                       0.00
# pension                                         0                       0.00
# employment_status                               0                       0.00
# main_activity                                   0                       0.00
# work_exp                                       11                       2.93
# job_satisfaction                                7                       1.87
#
#                              Unique Values Count
# is_income_30_days                              1
# sex                                            2
# birth_year                                    55
# age                                           99
# education                                     13
# diplom                                         5
# family                                         6
# proff_group                                    9
# is_ceo                                         2
# work_day_hours                                11
# settlement_type                                2
# industry                                      26
# income_30d                                    87
# additional_job                                 2
# birth_year2                                   55
# foreign_language                               2
# additional_health_insurance                    2
# region                                         2
# children                                       2
# pension                                        2
# employment_status                              1
# main_activity                                  6
# work_exp                                      50
# job_satisfaction                               5

# %%
df = df.dropna(subset=['work_day_hours', 'additional_job', 'foreign_language', 'education', 'industry', 'additional_health_insurance'])

# %%
df['region'].value_counts()
# Out:
# region
# 137.0    179
# 141.0    168
# Name: count, dtype: int64

# %%
print("Размерность датафрейма:")
print(df.shape)
print()
missing_values_count = df.isna().sum()  # Общее количество пропущенных значений
missing_values_percentage = (df.isna().mean() * 100).round(2)  # Процент пропущенных значений
unique_values_count = df.nunique()  # Количество уникальных значений в каждом столбце

missing_summary = pd.DataFrame({
    'Missing Values Count': missing_values_count,
    'Missing Values Percentage': missing_values_percentage,
    'Unique Values Count': unique_values_count
})

print("Сводка по отсутствующим значениям и уникальным значениям:")
display(missing_summary)
# Out:
# Размерность датафрейма:
# (347, 24)
#
# Сводка по отсутствующим значениям и уникальным значениям:
#                              Missing Values Count  Missing Values Percentage  \
# is_income_30_days                               0                       0.00
# sex                                             0                       0.00
# birth_year                                      0                       0.00
# age                                             0                       0.00
# education                                       0                       0.00
# diplom                                          0                       0.00
# family                                          0                       0.00
# proff_group                                     0                       0.00
# is_ceo                                          0                       0.00
# work_day_hours                                  0                       0.00
# settlement_type                                 0                       0.00
# industry                                        0                       0.00
# income_30d                                      0                       0.00
# additional_job                                  0                       0.00
# birth_year2                                     0                       0.00
# foreign_language                                0                       0.00
# additional_health_insurance                     0                       0.00
# region                                          0                       0.00
# children                                        0                       0.00
# pension                                         0                       0.00
# employment_status                               0                       0.00
# main_activity                                   0                       0.00
# work_exp                                        9                       2.59
# job_satisfaction                                5                       1.44
#
#                              Unique Values Count
# is_income_30_days                              1
# sex                                            2
# birth_year                                    55
# age                                           99
# education                                     13
# diplom                                         5
# family                                         6
# proff_group                                    9
# is_ceo                                         2
# work_day_hours                                11
# settlement_type                                2
# industry                                      26
# income_30d                                    82
# additional_job                                 2
# birth_year2                                   55
# foreign_language                               2
# additional_health_insurance                    2
# region                                         2
# children                                       2
# pension                                        2
# employment_status                              1
# main_activity                                  6
# work_exp                                      50
# job_satisfaction                               5

# %%
df = df.drop(['is_income_30_days'], axis=1)
# В этой колонке осталось всего одно уникальное значение, значит она константа и подлежит утилизации

# %%
# У нас две колонки с годом рождения
df = df.drop(['birth_year2', 'birth_year'], axis=1)

# %%
# Дропаю так как здесь константа - у всех есть работа
df = df.drop(['employment_status'], axis=1)

# %%
df['main_activity'].value_counts().sort_index()

# Подлежат обработке
# Дропаем education, main_activity industry, 

# при этом оставляем только diplom, делим на 3 группы 1, 2, 3
# family, 2 и 6 это в браке, остальные нет
# proff_group, (может коррелировать с is_ceo) - 1, 2 , 7 , 8 в одну группу (квал работники), остальных в другую
# Out:
# main_activity
# 5.0       1
# 6.0       6
# 11.0      4
# 12.0    304
# 13.0     30
# 16.0      2
# Name: count, dtype: int64

# %%
# Дропаем education, main_activity industry
len(df.columns)
df = df.drop(['education', 'industry'], axis=1)
# 'main_activity'

# %%
def replace_family(value):
    if value in [2, 6]:
        return 1 # В браке 
    else:
        return 2 # Не в браке 

# Функция для замены значений в колонке 'proff_group'
def replace_proff_group(value):
    if value in [1, 2, 7, 8]:
        return 1 # Проф работник
    else:
        return 2 # Не проф работник

# Функция для замены значений в колонке 'diplom'
def replace_diplom(value):
    if value in [1, 2, 3, 4]:
        return 1  #  Школота
    elif value == 5: 
        return 2 # Шаражники
    elif value == 6:
        return 3 # Челики с умом (дипломом шараги только ВУЗа)

# Применяем функции к соответствующим колонкам
df['family'] = df['family'].apply(replace_family)
df['proff_group'] = df['proff_group'].apply(replace_proff_group)
df['diplom'] = df['diplom'].apply(replace_diplom)

# %%
df['region'].value_counts()
# Out:
# region
# 137.0    179
# 141.0    168
# Name: count, dtype: int64

# %%
# # sns.scatterplot(data=df, y='income_30d', x = 'diplom', hue='diplom')
# sns.boxplot(data=df, y='income_30d', x = 'main_activity')#, hue='is_ceo')
# # plt.legend(loc=(1, 0))
# plt.xticks(rotation=60)
# plt.show()

# %%
# одну берем за базовую, например военнослужащие
# все остальные не военнослужащие
# Можно выбрать за базовую ту в которой больше всего наблюдений
# либо ту которая существенно отличается от остальных

# %%
df = df.dropna(subset=['work_exp'])

# %%
df = df.dropna(subset=['job_satisfaction'])

# "zj161.3y": "work_exp",
# "zj1.1.1": "job_satisfaction"

# %%
df = df.drop([3170, 6329, 1942, 7887, 11805, 7068, 7084], axis=0)

# %% [markdown]
# ## Проверка корреляции

# %%
# np.linalg.cond(df)

# %%
df.shape
# Out:
# (326, 18)

# %%
df = df[df['region'] == 141].copy()
df = df.drop('region', axis=1)

# %%
df.shape
# Out:
# (150, 17)

# %%
# np.linalg.cond(df)

# %%
corr = df.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
fig, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(corr,
    mask=mask,
    cmap=sns.diverging_palette(250, 250, as_cmap=True),
    annot = True,
    vmin=-1.0, vmax=1.0, # всегда ставить от -1 до 1 ставим два одинаковых цвета на оба конца
    square=True,
    ax=ax);

# %%
# df['zj161.3y'].value_counts().sort_index()

# %%
# df['additional_job'].value_counts()
# df.nunique()

# %% [markdown]
# ## Построение моделей

# %%
# clear_df = clear_df.rename(columns=data_dict)

# %%
# clear_df
# df = df[df['region'] == 137].copy()
# df = df.drop('foreign_language', axis=1)
df['age'] = df['age'] - df['age'].mean()
df['age^2'] = -df['age'] ** 2

# %%
df = df.rename({'additional_health_insurance': 'add_ins', 'job_satisfaction': 'job_sat', 'foreign_language': 'for_lan'}, axis=1)

# %%
y = np.log(df["income_30d"])
# X = df.drop(["income_30d", 'work_day_hours', 'additional_job', 'foreign_language', 'additional_health_insurance', 'settlement_type'], axis=1)
X = df.drop(["income_30d", 'settlement_type', 'additional_job', 'children', 'pension', 'work_day_hours', 'age^2', 'age', 'is_ceo'], axis=1)#, 'zj161.3y', 'foreign_language', 'additional_health_insurance', 'additional_job'], axis=1)
# 'settlement_type

X = sm.add_constant(X)
model1 = sm.OLS(y, X).fit()

results_table = model1.summary()
print(results_table)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             income_30d   R-squared:                       0.412
# Model:                            OLS   Adj. R-squared:                  0.375
# Method:                 Least Squares   F-statistic:                     10.92
# Date:                Wed, 18 Dec 2024   Prob (F-statistic):           9.10e-13
# Time:                        20:51:12   Log-Likelihood:                -14.798
# No. Observations:                 150   AIC:                             49.60
# Df Residuals:                     140   BIC:                             79.70
# Df Model:                           9
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             9.8797      0.427     23.124      0.000       9.035      10.724
# sex              -0.0538      0.053     -1.024      0.308      -0.158       0.050
# diplom            0.0967      0.030      3.199      0.002       0.037       0.156
# family           -0.1247      0.048     -2.620      0.010      -0.219      -0.031
# proff_group      -0.0861      0.053     -1.624      0.107      -0.191       0.019
# for_lan           0.0104      0.054      0.193      0.847      -0.096       0.117
# add_ins          -0.4040      0.073     -5.557      0.000      -0.548      -0.260
# main_activity     0.1414      0.030      4.710      0.000       0.082       0.201
# work_exp         -0.0002      0.002     -0.091      0.928      -0.004       0.004
# job_sat          -0.0908      0.028     -3.289      0.001      -0.145      -0.036
# ==============================================================================
# Omnibus:                        0.691   Durbin-Watson:                   1.781
# Prob(Omnibus):                  0.708   Jarque-Bera (JB):                0.819
# Skew:                          -0.138   Prob(JB):                        0.664
# Kurtosis:                       2.765   Cond. No.                         471.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y = np.log(df["income_30d"])
# X = df.drop(["income_30d", 'work_day_hours', 'additional_job', 'foreign_language', 'additional_health_insurance', 'settlement_type'], axis=1)
X = df.drop(["income_30d", 'settlement_type', 'additional_job', 'children', 'pension', 'work_day_hours', 'age^2', 'age'], axis=1)#, 'zj161.3y', 'foreign_language', 'additional_health_insurance', 'additional_job'], axis=1)
# 'settlement_type

X = sm.add_constant(X)
model2 = sm.OLS(y, X).fit()

results_table = model2.summary()
print(results_table)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             income_30d   R-squared:                       0.441
# Model:                            OLS   Adj. R-squared:                  0.401
# Method:                 Least Squares   F-statistic:                     10.96
# Date:                Wed, 18 Dec 2024   Prob (F-statistic):           1.29e-13
# Time:                        20:51:12   Log-Likelihood:                -11.081
# No. Observations:                 150   AIC:                             44.16
# Df Residuals:                     139   BIC:                             77.28
# Df Model:                          10
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             9.9907      0.420     23.766      0.000       9.160      10.822
# sex              -0.0553      0.051     -1.075      0.284      -0.157       0.046
# diplom            0.0977      0.030      3.303      0.001       0.039       0.156
# family           -0.0972      0.048     -2.036      0.044      -0.192      -0.003
# proff_group      -0.1028      0.052     -1.967      0.051      -0.206       0.001
# is_ceo           -0.1849      0.070     -2.658      0.009      -0.322      -0.047
# for_lan           0.0258      0.053      0.487      0.627      -0.079       0.130
# add_ins          -0.3636      0.073     -4.997      0.000      -0.507      -0.220
# main_activity     0.1501      0.030      5.074      0.000       0.092       0.209
# work_exp         -0.0004      0.002     -0.192      0.848      -0.004       0.004
# job_sat          -0.0819      0.027     -3.006      0.003      -0.136      -0.028
# ==============================================================================
# Omnibus:                        1.990   Durbin-Watson:                   1.829
# Prob(Omnibus):                  0.370   Jarque-Bera (JB):                1.978
# Skew:                          -0.218   Prob(JB):                        0.372
# Kurtosis:                       2.643   Cond. No.                         474.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y = np.log(df["income_30d"])
# X = df.drop(["income_30d", 'work_day_hours', 'additional_job', 'foreign_language', 'additional_health_insurance', 'settlement_type'], axis=1)
X = df.drop(["income_30d", 'settlement_type', 'additional_job', 'children', 'pension', 'work_day_hours', 'age^2'], axis=1)#, 'zj161.3y', 'foreign_language', 'additional_health_insurance', 'additional_job'], axis=1)
# 'settlement_type

X = sm.add_constant(X)
model3 = sm.OLS(y, X).fit()

results_table = model3.summary()
print(results_table)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             income_30d   R-squared:                       0.501
# Model:                            OLS   Adj. R-squared:                  0.462
# Method:                 Least Squares   F-statistic:                     12.62
# Date:                Wed, 18 Dec 2024   Prob (F-statistic):           2.84e-16
# Time:                        20:51:12   Log-Likelihood:                -2.4761
# No. Observations:                 150   AIC:                             28.95
# Df Residuals:                     138   BIC:                             65.08
# Df Model:                          11
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             9.4266      0.422     22.364      0.000       8.593      10.260
# sex              -0.0657      0.049     -1.347      0.180      -0.162       0.031
# age              -0.0135      0.003     -4.096      0.000      -0.020      -0.007
# diplom            0.1111      0.028      3.936      0.000       0.055       0.167
# family           -0.0906      0.045     -2.002      0.047      -0.180      -0.001
# proff_group      -0.1116      0.050     -2.251      0.026      -0.210      -0.014
# is_ceo           -0.2007      0.066     -3.040      0.003      -0.331      -0.070
# for_lan           0.0598      0.051      1.176      0.242      -0.041       0.160
# add_ins          -0.2947      0.071     -4.152      0.000      -0.435      -0.154
# main_activity     0.1623      0.028      5.758      0.000       0.107       0.218
# work_exp          0.0113      0.003      3.283      0.001       0.004       0.018
# job_sat          -0.0613      0.026     -2.330      0.021      -0.113      -0.009
# ==============================================================================
# Omnibus:                        2.391   Durbin-Watson:                   1.810
# Prob(Omnibus):                  0.303   Jarque-Bera (JB):                1.799
# Skew:                          -0.083   Prob(JB):                        0.407
# Kurtosis:                       2.490   Cond. No.                         512.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y = np.log(df["income_30d"])
# X = df.drop(["income_30d", 'work_day_hours', 'additional_job', 'foreign_language', 'additional_health_insurance', 'settlement_type'], axis=1)
X = df.drop(["income_30d", 'settlement_type', 'additional_job', 'children', 'pension', 'work_day_hours'], axis=1)#, 'zj161.3y', 'foreign_language', 'additional_health_insurance', 'additional_job'], axis=1)
# 'settlement_type

X = sm.add_constant(X)
model = sm.OLS(y, X).fit()

results_table = model.summary()
print(results_table)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             income_30d   R-squared:                       0.507
# Model:                            OLS   Adj. R-squared:                  0.464
# Method:                 Least Squares   F-statistic:                     11.76
# Date:                Wed, 18 Dec 2024   Prob (F-statistic):           4.86e-16
# Time:                        20:51:12   Log-Likelihood:                -1.5791
# No. Observations:                 150   AIC:                             29.16
# Df Residuals:                     137   BIC:                             68.30
# Df Model:                          12
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             9.5011      0.425     22.382      0.000       8.662      10.341
# sex              -0.0711      0.049     -1.456      0.148      -0.168       0.025
# age              -0.0125      0.003     -3.701      0.000      -0.019      -0.006
# diplom            0.1113      0.028      3.950      0.000       0.056       0.167
# family           -0.0792      0.046     -1.720      0.088      -0.170       0.012
# proff_group      -0.1108      0.049     -2.239      0.027      -0.209      -0.013
# is_ceo           -0.2098      0.066     -3.166      0.002      -0.341      -0.079
# for_lan           0.0506      0.051      0.990      0.324      -0.051       0.152
# add_ins          -0.2981      0.071     -4.206      0.000      -0.438      -0.158
# main_activity     0.1611      0.028      5.725      0.000       0.105       0.217
# work_exp          0.0111      0.003      3.237      0.002       0.004       0.018
# job_sat          -0.0623      0.026     -2.374      0.019      -0.114      -0.010
# age^2             0.0002      0.000      1.284      0.201   -9.75e-05       0.000
# ==============================================================================
# Omnibus:                        1.370   Durbin-Watson:                   1.773
# Prob(Omnibus):                  0.504   Jarque-Bera (JB):                1.205
# Skew:                          -0.028   Prob(JB):                        0.548
# Kurtosis:                       2.565   Cond. No.                     4.61e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.61e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
df.columns
# Out:
# Index(['sex', 'age', 'diplom', 'family', 'proff_group', 'is_ceo',
#        'work_day_hours', 'settlement_type', 'income_30d', 'additional_job',
#        'for_lan', 'add_ins', 'children', 'pension', 'main_activity',
#        'work_exp', 'job_sat', 'age^2'],
#       dtype='object')

# %%
# Нулевая гипотеза (H0): Коэффициент равен нулю, то есть переменная не имеет значимого влияния на зависимую переменную.
# Альтернативная гипотеза (H1): Коэффициент не равен нулю, то есть переменная имеет значимое влияние на зависимую переменную.

# P-value: Это вероятность получения наблюдаемых данных (или более экстремальных), если нулевая гипотеза верна.
# Если P-value меньше выбранного уровня значимости (обычно 0.05), это означает, что вероятность получения таких данных при верной 
# нулевой гипотезе слишком мала. Поэтому мы отвергаем нулевую гипотезу и принимаем, что коэффициент значим.

# Если P-value меньше 0.05, нулевая гипотеза отвергается, и коэффициент считается значимым.
# Если P-value больше или равно 0.05, нулевая гипотеза не отвергается, и коэффициент считается незначимым.

# %% [markdown]
# ## Проверка предпосылок

# %%
# # Проверка автокорреляции (нужно только для данных зависимых во времени)

# dw_test = durbin_watson(model.resid)
# print(f"Durbin-Watson statistic: {dw_test}")

# %%
# Тест Дарбина-Уотсона возвращает значение статистики, которое лежит в диапазоне от 0 до 4. Интерпретация этого значения следующая:

# Значение около 2 предполагает отсутствие автокорреляции.
# Значение, значительно меньшее 2, предполагает положительную автокорреляцию.
# Значение, значительно большее 2, предполагает отрицательную автокорреляцию.

# %%
# Тест Бройша-Пагана:

# Применяется, если есть подозрения на гетероскедастичность (непостоянную дисперсию ошибок).
# Проверяет, что дисперсия ошибок постоянна.

# Проведение теста Бройша-Пагана
bp_test = het_breuschpagan(model.resid, model.model.exog)
labels = ['LM Statistic', 'LM-Test p-value', 'F-Statistic', 'F-Test p-value']
print(dict(zip(labels, bp_test)))
# Out:
# {'LM Statistic': 11.080298935075989, 'LM-Test p-value': 0.5220498875352775, 'F-Statistic': 0.9105985582971027, 'F-Test p-value': 0.5382512750892479}

# %%
# LM Statistic: Лагранжева мультипликативная статистика (LM Statistic) — это тестовая статистика. 
# Она используется для проверки гипотезы о гомоскедастичности.

# LM-Test p-value: Значение p-value для LM Statistic. 
# Если это значение меньше уровня значимости (например, 0.05), то гипотеза о гомоскедастичности отвергается, 
# и можно предположить наличие гетероскедастичности.

# F-Statistic: Статистика F-теста. Используется для проверки гомоскедастичности.
    
# F-Test p-value: Значение p-value для F-Statistic. Если это значение меньше уровня значимости (например, 0.05), 
# то гипотеза о гомоскедастичности отвергается.

# Нарушение гомоскедастичности (гетероскедастичность) приводит к неэффективности оценок и недостоверности стандартных ошибок и тестов значимости!!!!!

# %%
white_test = het_white(model.resid, model.model.exog)
labels = ['Test Statistic', 'Test Statistic p-value', 'F-Statistic', 'F-Statistic p-value']
print(dict(zip(labels, white_test)))
# Out:
# {'Test Statistic': 67.52291831763654, 'Test Statistic p-value': 0.8179861285294483, 'F-Statistic': 0.7254189010076243, 'F-Statistic p-value': 0.9168780783974992}

# %%
# Test Statistic: Статистика теста Уайта.

# Test Statistic p-value: Значение p-value для статистики теста Уайта. Если это значение меньше уровня значимости (например, 0.05), 
# то гипотеза о гомоскедастичности отвергается, и можно предположить наличие гетероскедастичности.

# F-Statistic: Статистика F-теста.
    
# F-Statistic p-value: Значение p-value для F-Statistic. Если это значение меньше уровня значимости (например, 0.05), 
# то гипотеза о гомоскедастичности отвергается.

# %%
# Тест Шапиро-Уилка:

# Применяется для проверки нормальности распределения остатков.
# Подходит для малых и средних выборок данных.

# Проведение теста Шапиро-Уилка
shapiro_test = stats.shapiro(model.resid)
print(f"Shapiro-Wilk test: {shapiro_test}")

# Q-Q plot
sm.qqplot(model.resid, line='s')
plt.show()

# Гистограмма остатков
sns.histplot(model.resid, kde=True, bins=30)
plt.xlabel('Residuals')
plt.title('Histogram of Residuals')
plt.show()

# если p-value > 0.05 то данные нормально распределены
# Out:
# Shapiro-Wilk test: ShapiroResult(statistic=0.9934985664872698, pvalue=0.736534406375443)

# %%
# Проверка мультиколлинеарности

vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(vif_data)
# Out:
#           feature         VIF
# 0           const  412.874233
# 1             sex    1.366994
# 2             age    4.037733
# 3          diplom    1.307135
# 4          family    1.209886
# 5     proff_group    1.399699
# 6          is_ceo    1.162216
# 7         for_lan    1.431786
# 8         add_ins    1.156171
# 9   main_activity    1.109486
# 10       work_exp    3.879228
# 11        job_sat    1.224833
# 12          age^2    1.205745

# %%
from scipy.stats import zscore
outlier_indices = model.resid[abs(zscore(model.resid)) > 2.5].index
print("Индексы выбросов:")
print(outlier_indices)
# Out:
# Индексы выбросов:
# Index([], dtype='int64')

# %% [markdown]
# ## Борьба с гетероскедастичностью - использование робастных стандартных ошибок

# %%
# # Проведение теста Бройша-Пагана
# bp_test = het_breuschpagan(robust_model.resid, robust_model.model.exog)
# labels = ['LM Statistic', 'LM-Test p-value', 'F-Statistic', 'F-Test p-value']
# print(dict(zip(labels, bp_test)))

# %%
# # Построение модели с робастными стандартными ошибками
# robust_model = sm.OLS(y, X).fit(cov_type='HC1')

# # Получение результатов модели
# results_table = robust_model.summary()
# print(results_table)

# %%
# white_test = het_white(robust_model.resid, robust_model.model.exog)
# labels = ['Test Statistic', 'Test Statistic p-value', 'F-Statistic', 'F-Statistic p-value']
# print(dict(zip(labels, white_test)))

# %%
import statsmodels.api as sm
from stargazer.stargazer import Stargazer

# %%
stargazer = Stargazer([model1, model2, model3, model])
stargazer.custom_columns(["Модель1", "Модель2", 'Модель3', 'Модель'], [1, 1, 1, 1])
stargazer
# Out:
# <table style="text-align:center"><tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="4"><em>Dependent variable: income_30d</em></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">Модель1</td><td colspan="1">Модель2</td><td colspan="1">Модель3</td><td colspan="1">Модель</td></tr><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">add_ins</td><td>-0.404<sup>***</sup></td><td>-0.364<sup>***</sup></td><td>-0.295<sup>***</sup></td><td>-0.298<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.073)</td><td>(0.073)</td><td>(0.071)</td><td>(0.071)</td></tr>
# <tr><td style="text-align:left">age</td><td></td><td></td><td>-0.013<sup>***</sup></td><td>-0.012<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td>(0.003)</td><td>(0.003)</td></tr>
# <tr><td style="text-align:left">age^2</td><td></td><td></td><td></td><td>0.000<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td>(0.000)</td></tr>
# <tr><td style="text-align:left">const</td><td>9.880<sup>***</sup></td><td>9.991<sup>***</sup></td><td>9.427<sup>***</sup></td><td>9.501<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.427)</td><td>(0.420)</td><td>(0.422)</td><td>(0.425)</td></tr>
# <tr><td style="text-align:left">diplom</td><td>0.097<sup>***</sup></td><td>0.098<sup>***</sup></td><td>0.111<sup>***</sup></td><td>0.111<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.030)</td><td>(0.030)</td><td>(0.028)</td><td>(0.028)</td></tr>
# <tr><td style="text-align:left">family</td><td>-0.125<sup>***</sup></td><td>-0.097<sup>**</sup></td><td>-0.091<sup>**</sup></td><td>-0.079<sup>*</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.048)</td><td>(0.048)</td><td>(0.045)</td><td>(0.046)</td></tr>
# <tr><td style="text-align:left">for_lan</td><td>0.010<sup></sup></td><td>0.026<sup></sup></td><td>0.060<sup></sup></td><td>0.051<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.054)</td><td>(0.053)</td><td>(0.051)</td><td>(0.051)</td></tr>
# <tr><td style="text-align:left">is_ceo</td><td></td><td>-0.185<sup>***</sup></td><td>-0.201<sup>***</sup></td><td>-0.210<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.070)</td><td>(0.066)</td><td>(0.066)</td></tr>
# <tr><td style="text-align:left">job_sat</td><td>-0.091<sup>***</sup></td><td>-0.082<sup>***</sup></td><td>-0.061<sup>**</sup></td><td>-0.062<sup>**</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.028)</td><td>(0.027)</td><td>(0.026)</td><td>(0.026)</td></tr>
# <tr><td style="text-align:left">main_activity</td><td>0.141<sup>***</sup></td><td>0.150<sup>***</sup></td><td>0.162<sup>***</sup></td><td>0.161<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.030)</td><td>(0.030)</td><td>(0.028)</td><td>(0.028)</td></tr>
# <tr><td style="text-align:left">proff_group</td><td>-0.086<sup></sup></td><td>-0.103<sup>*</sup></td><td>-0.112<sup>**</sup></td><td>-0.111<sup>**</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.053)</td><td>(0.052)</td><td>(0.050)</td><td>(0.049)</td></tr>
# <tr><td style="text-align:left">sex</td><td>-0.054<sup></sup></td><td>-0.055<sup></sup></td><td>-0.066<sup></sup></td><td>-0.071<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.053)</td><td>(0.051)</td><td>(0.049)</td><td>(0.049)</td></tr>
# <tr><td style="text-align:left">work_exp</td><td>-0.000<sup></sup></td><td>-0.000<sup></sup></td><td>0.011<sup>***</sup></td><td>0.011<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.002)</td><td>(0.002)</td><td>(0.003)</td><td>(0.003)</td></tr>
#
# <td colspan="5" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>150</td><td>150</td><td>150</td><td>150</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.412</td><td>0.441</td><td>0.501</td><td>0.507</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.375</td><td>0.401</td><td>0.462</td><td>0.464</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>0.276 (df=140)</td><td>0.271 (df=139)</td><td>0.256 (df=138)</td><td>0.256 (df=137)</td></tr><tr><td style="text-align: left">F Statistic</td><td>10.919<sup>***</sup> (df=9; 140)</td><td>10.959<sup>***</sup> (df=10; 139)</td><td>12.618<sup>***</sup> (df=11; 138)</td><td>11.759<sup>***</sup> (df=12; 137)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="4" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>

# %%
X.columns
# Out:
# Index(['const', 'sex', 'age', 'diplom', 'family', 'proff_group', 'is_ceo',
#        'for_lan', 'add_ins', 'main_activity', 'work_exp', 'job_sat', 'age^2'],
#       dtype='object')

# %%
X
# Out:
#        const  sex    age  diplom  family  proff_group  is_ceo  for_lan  \
# 1943     1.0  2.0   3.65       3       2            2     2.0      2.0
# 1945     1.0  2.0 -18.35       1       2            2     1.0      1.0
# 1948     1.0  2.0   8.15       2       2            2     2.0      2.0
# 1958     1.0  2.0  25.15       3       1            1     2.0      2.0
# 1959     1.0  1.0  -7.85       3       1            1     2.0      2.0
# ...      ...  ...    ...     ...     ...          ...     ...      ...
# 11806    1.0  2.0 -11.35       3       1            1     2.0      1.0
# 11814    1.0  1.0  -4.35       1       1            1     2.0      2.0
# 11815    1.0  2.0  -6.85       1       1            2     2.0      2.0
# 11820    1.0  2.0 -22.85       2       2            2     1.0      1.0
# 11824    1.0  1.0  10.15       2       2            1     2.0      2.0
#
#        add_ins  main_activity  work_exp  job_sat     age^2
# 1943       2.0           12.0      26.0      3.0  -13.3225
# 1945       2.0           12.0       4.0      4.0 -336.7225
# 1948       2.0           12.0      15.0      3.0  -66.4225
# 1958       2.0           12.0      43.0      2.0 -632.5225
# 1959       2.0           12.0      16.0      2.0  -61.6225
# ...        ...            ...       ...      ...       ...
# 11806      2.0           12.0       7.0      1.0 -128.8225
# 11814      2.0           12.0      17.0      2.0  -18.9225
# 11815      2.0           12.0      15.0      3.0  -46.9225
# 11820      2.0           12.0       1.0      2.0 -522.1225
# 11824      2.0           12.0      30.0      2.0 -103.0225
#
# [150 rows x 13 columns]

# %%
X.describe().T
# Out:
#                count          mean         std       min       25%      50%  \
# const          150.0  1.000000e+00    0.000000    1.0000    1.0000   1.0000
# sex            150.0  1.506667e+00    0.501630    1.0000    1.0000   2.0000
# age            150.0 -1.136868e-15   12.488485  -22.8500   -9.8500  -2.3500
# diplom         150.0  1.973333e+00    0.850950    1.0000    1.0000   2.0000
# family         150.0  1.526667e+00    0.500961    1.0000    1.0000   2.0000
# proff_group    150.0  1.520000e+00    0.501274    1.0000    1.0000   2.0000
# is_ceo         150.0  1.866667e+00    0.341073    1.0000    2.0000   2.0000
# for_lan        150.0  1.606667e+00    0.490126    1.0000    1.0000   2.0000
# add_ins        150.0  1.886667e+00    0.318062    1.0000    2.0000   2.0000
# main_activity  150.0  1.196000e+01    0.784754    5.0000   12.0000  12.0000
# work_exp       150.0  1.850667e+01   12.048418    0.0000    9.0000  16.0000
# job_sat        150.0  1.940000e+00    0.884088    1.0000    1.0000   2.0000
# age^2          150.0 -1.549225e+02  163.683635 -764.5225 -234.0975 -97.0225
#
#                    75%      max
# const           1.0000   1.0000
# sex             2.0000   2.0000
# age             9.5250  27.6500
# diplom          3.0000   3.0000
# family          2.0000   2.0000
# proff_group     2.0000   2.0000
# is_ceo          2.0000   2.0000
# for_lan         2.0000   2.0000
# add_ins         2.0000   2.0000
# main_activity  12.0000  13.0000
# work_exp       26.0000  48.0000
# job_sat         2.0000   5.0000
# age^2         -23.5225  -0.0225
