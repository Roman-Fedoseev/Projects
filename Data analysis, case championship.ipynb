# %%
# Импорт данных с кейса

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:\\Users\\MadBoss\\Desktop\\проги на питоне\\UNZIP_ME_FOR_NOTEBOOKS_ML_RUS_V6\\UNZIP_ME_FOR_NOTEBOOKS_ML_RUS_V6\\DATA\\Кейс-чемпионат.csv')

# %%
df['Series Name'].unique()
# Out:
# array(['Industry (including construction), value added (% of GDP)',
#        'Agriculture, forestry, and fishing, value added (% of GDP)',
#        'GDP (current US$)', 'GDP growth (annual %)',
#        'Government expenditure on education, total (% of GDP)',
#        'Imports of goods and services (% of GDP)',
#        'Manufacturing, value added (% of GDP)',
#        'Merchandise trade (% of GDP)', 'Military expenditure (% of GDP)',
#        'Research and development expenditure (% of GDP)',
#        'Services, value added (% of GDP)', 'Trade (% of GDP)',
#        'Trade in services (% of GDP)',
#        'Exports of goods and services (% of GDP)',
#        'Domestic general government health expenditure (% of GDP)',
#        'Textiles and clothing (% of value added in manufacturing)',
#        'Other manufacturing (% of value added in manufacturing)',
#        'Machinery and transport equipment (% of value added in manufacturing)',
# ...

# %%
df = df[df['Country Name'].isin(['Algeria', 'Ethiopia', 'Namibia', 'South Africa', 'Egypt, Arab Rep.', 'Iran, Islamic Rep.', 'Pakistan', 'Saudi Arabia', 'Turkiye', 'Belarus', 'Moldova', 'Serbia', 'China', 'Mongolia', 'Armenia', 'Azerbaijan', 'Argentina', 'Brazil', 'Mexico', 'Peru', 'Kazakhstan', 'Kyrgyz Republic', 'Tajikistan', 'Turkmenistan', 'Uzbekistan', 'Indonesia', 'Malaysia', 'Philippines', 'Thailand', 'Vietnam', 'India'])]

# %%
df['Country Name'].unique()
# Out:
# array(['Algeria', 'Argentina', 'Armenia', 'Azerbaijan', 'Belarus',
#        'Brazil', 'China', 'Egypt, Arab Rep.', 'Ethiopia', 'India',
#        'Indonesia', 'Iran, Islamic Rep.', 'Kazakhstan', 'Kyrgyz Republic',
#        'Malaysia', 'Mexico', 'Moldova', 'Mongolia', 'Namibia', 'Pakistan',
#        'Peru', 'Philippines', 'Saudi Arabia', 'Serbia', 'South Africa',
#        'Tajikistan', 'Thailand', 'Turkiye', 'Turkmenistan', 'Uzbekistan',
#        'Vietnam'], dtype=object)

# %%
len(df['Country Name'].unique())
# Out:
# 31

# %%
# table = new_df[new_df["Дружественная страна?"] == "Да"].groupby(by="Country Name")

# %%
# Проанализировать сколько где каких представительств для каждой страны

# %%
# group_df = new_df.sort_values(['Country Name', 'Представительство McKinsey', 'Представительство Bain', 'Представительство BCG', 
#                    'Представительство Deloitte', 'Представительство PricewaterhouseCoopers',
#                    'Представительство Ernst & Young', 'Представительство KPMG']).groupby('Country Name').max()

# [['Country Name', 'Представительство McKinsey', 'Представительство Bain', 'Представительство BCG', 'Представительство Deloitte', 'Представительство PricewaterhouseCoopers','Представительство Ernst & Young', 'Представительство KPMG']]

# %%
# group_df.sort_values(['Country Name', 'Представительство McKinsey', 'Представительство Bain', 'Представительство BCG', 'Представительство Deloitte', 'Представительство PricewaterhouseCoopers','Представительство Ernst & Young', 'Представительство KPMG'])

# %%
df['Представительство McKinsey'].unique()
# Out:
# array([nan, 'Есть'], dtype=object)

# %%
df['Представительство Bain'].unique()
# Out:
# array([nan, 'Есть'], dtype=object)

# %%
df['Представительство BCG'].unique()
# Out:
# array([nan, 'Есть'], dtype=object)

# %%
df['Представительство Deloitte'].unique()
# Out:
# array([nan, 'Есть'], dtype=object)

# %%
df['Представительство PricewaterhouseCoopers'].unique()
# Out:
# array([nan, 'Есть'], dtype=object)

# %%
df['Представительство Ernst & Young'].unique()
# Out:
# array(['Есть', nan], dtype=object)

# %%
df['Представительство KPMG'].unique()
# Out:
# array(['Есть', nan], dtype=object)

# %%
# Везде значения nan либо 'есть'
# заменяю значения nan на 0, 'есть' на 1

# %%
df = df.fillna(0)

# %%
def replace_est(x):
    if x == 'Есть':
        x = 1
    return(x)

# %%
df = df[['Country Name', 'Представительство McKinsey', 'Представительство Bain', 'Представительство BCG', 'Представительство Deloitte', 'Представительство PricewaterhouseCoopers','Представительство Ernst & Young', 'Представительство KPMG']]
# Оставляю маленький датафрейм только с нужными колонками 
df
# Out:
#       Country Name Представительство McKinsey Представительство Bain  \
# 2          Algeria                          0                      0
# 7        Argentina                       Есть                      0
# 8          Armenia                          0                      0
# 12      Azerbaijan                          0                      0
# 17         Belarus                          0                      0
# ...            ...                        ...                    ...
# 5246      Thailand                          0                   Есть
# 5252       Turkiye                       Есть                   Есть
# 5253  Turkmenistan                          0                      0
# 5262    Uzbekistan                          0                      0
# 5265       Vietnam                       Есть                   Есть
#
#      Представительство BCG Представительство Deloitte  \
# 2                        0                          0
# ...

# %%
df['Представительство McKinsey'] = df['Представительство McKinsey'].apply(replace_est) 

df['Представительство Bain'] = df['Представительство Bain'].apply(replace_est) 

df['Представительство BCG'] = df['Представительство BCG'].apply(replace_est) 

df['Представительство Deloitte'] = df['Представительство Deloitte'].apply(replace_est) 

df['Представительство PricewaterhouseCoopers'] = df['Представительство PricewaterhouseCoopers'].apply(replace_est) 

df['Представительство Ernst & Young'] = df['Представительство Ernst & Young'].apply(replace_est) 

df['Представительство KPMG'] = df['Представительство KPMG'].apply(replace_est)

# %%
df.sort_values(['Country Name', 'Представительство McKinsey', 'Представительство Bain', 'Представительство BCG', 'Представительство Deloitte', 'Представительство PricewaterhouseCoopers','Представительство Ernst & Young', 'Представительство KPMG'])
# Out:
#      Country Name  Представительство McKinsey  Представительство Bain  \
# 2         Algeria                           0                       0
# 268       Algeria                           0                       0
# 534       Algeria                           0                       0
# 800       Algeria                           0                       0
# 1066      Algeria                           0                       0
# ...           ...                         ...                     ...
# 4201      Vietnam                           1                       1
# 4467      Vietnam                           1                       1
# 4733      Vietnam                           1                       1
# 4999      Vietnam                           1                       1
# 5265      Vietnam                           1                       1
#
#       Представительство BCG  Представительство Deloitte  \
# 2                         0                           0
# ...

# %%
new_df = df.groupby('Country Name').sum()
new_df
# Out:
#                     Представительство McKinsey  Представительство Bain  \
# Country Name
# Algeria                                      0                       0
# Argentina                                   20                       0
# Armenia                                      0                       0
# Azerbaijan                                   0                       0
# Belarus                                      0                       0
# Brazil                                      20                       0
# China                                       20                      20
# Egypt, Arab Rep.                            20                       0
# Ethiopia                                    20                       0
# India                                       20                      20
# Indonesia                                   20                      20
# Iran, Islamic Rep.                           0                       0
# ...

# %%
# new_df.sum(axis=1)
new_df['Суммарные значения'] = new_df.sum(axis=1)

# %%
new_df = new_df.sort_values('Суммарные значения', ascending=False)

# %%
itog_df = new_df['Суммарные значения'].apply(lambda x: x / 20)

# %%
# new_df.sort_values()

# %%
# visual_df.sort_values('Суммарные значения', ascending=False)

# %%
itog_df
# Out:
# Country Name
# Vietnam               7.0
# Turkiye               7.0
# China                 7.0
# India                 7.0
# Brazil                6.0
# Egypt, Arab Rep.      6.0
# Serbia                6.0
# Uzbekistan            5.0
# Thailand              5.0
# Philippines           5.0
# Kazakhstan            5.0
# Kyrgyz Republic       5.0
# Argentina             4.0
# Moldova               4.0
# Mexico                4.0
# Malaysia              4.0
# Azerbaijan            4.0
# Armenia               4.0
# Namibia               3.0
# Pakistan              3.0
# Peru                  3.0
# Indonesia             3.0
# Saudi Arabia          3.0
# South Africa          3.0
# Tajikistan            3.0
# Mongolia              2.0
# Belarus               2.0
# Algeria               2.0
# Ethiopia              1.0
# Iran, Islamic Rep.    0.0
# Turkmenistan          0.0
# Name: Суммарные значения, dtype: float64

# %%
visual_df = new_df.reset_index()[['Country Name', 'Суммарные значения']]
visual_df['Суммарные значения'] = visual_df['Суммарные значения'].apply(lambda x: x/20)
visual_df.sort_values('Country Name')
# Out:
#           Country Name  Суммарные значения
# 27             Algeria                 2.0
# 12           Argentina                 4.0
# 17             Armenia                 4.0
# 16          Azerbaijan                 4.0
# 26             Belarus                 2.0
# 4               Brazil                 6.0
# 2                China                 7.0
# 5     Egypt, Arab Rep.                 6.0
# 28            Ethiopia                 1.0
# 3                India                 7.0
# 21           Indonesia                 3.0
# 29  Iran, Islamic Rep.                 0.0
# 10          Kazakhstan                 5.0
# 11     Kyrgyz Republic                 5.0
# 15            Malaysia                 4.0
# 14              Mexico                 4.0
# 13             Moldova                 4.0
# 25            Mongolia                 2.0
# 18             Namibia                 3.0
# 19            Pakistan                 3.0
# 20                Peru                 3.0
# ...

# %%
sns.scatterplot(data=visual_df, y='Country Name', x='Суммарные значения')
# Out:
# <AxesSubplot:xlabel='Суммарные значения', ylabel='Country Name'>

# %%
# df[df['Country Name'].isin(['Algeria', 'Ethiopia', 'Namibia', 'South Africa', 'Egypt, Arab Rep.', 'Iran, Islamic Rep.', 'Pakistan', 'Saudi Arabia', 'Turkiye', 'Belarus', 'Moldova', 'Serbia', 'China', 'Mongolia', 'Armenia', 'Azerbaijan', 'Argentina', 'Brazil', 'Mexico', 'Peru', 'Kazakhstan', 'Kyrgyz Republic', 'Tajikistan', 'Turkmenistan', 'Uzbekistan', 'Indonesia', 'Malaysia', 'Philippines', 'Thailand', 'Vietnam', 'India'])]

# %%
# Agriculture, forestry, and fishing, value added (% of GDP)
# Textiles and clothing (% of value added in manufacturing)
new_df = pd.read_csv('C:\\Users\\MadBoss\\Desktop\\проги на питоне\\UNZIP_ME_FOR_NOTEBOOKS_ML_RUS_V6\\UNZIP_ME_FOR_NOTEBOOKS_ML_RUS_V6\\DATA\\Кейс-чемпионат.csv')

# %%
new_df
# Out:
#                                             Series Name      Region  \
# 0     Industry (including construction), value added...  Южная Азия
# 1     Industry (including construction), value added...         NaN
# 2     Industry (including construction), value added...      Африка
# 3     Industry (including construction), value added...         NaN
# 4     Industry (including construction), value added...         NaN
# ...                                                 ...         ...
# 5320                                                NaN         NaN
# 5321                                                NaN         NaN
# 5322                                                NaN         NaN
# 5323   Data from database: World Development Indicators         NaN
# 5324                           Last Updated: 09/19/2023         NaN
#
#         Country Name Дружественная страна? 2018 [YR2018] 2019 [YR2019]  \
# 0        Afghanistan                    Да   13,38724696   14,05811237
# ...

# %%
new_df = new_df.fillna(0)
new_df[new_df['Series Name'] == 'Government expenditure on education, total (% of GDP)']
# Out:
#                                             Series Name      Region  \
# 1064  Government expenditure on education, total (% ...  Южная Азия
# 1065  Government expenditure on education, total (% ...           0
# 1066  Government expenditure on education, total (% ...      Африка
# 1067  Government expenditure on education, total (% ...           0
# 1068  Government expenditure on education, total (% ...           0
# ...                                                 ...         ...
# 1325  Government expenditure on education, total (% ...           0
# 1326  Government expenditure on education, total (% ...           0
# 1327  Government expenditure on education, total (% ...           0
# 1328  Government expenditure on education, total (% ...           0
# 1329  Government expenditure on education, total (% ...           0
#
#                                     Country Name Дружественная страна?  \
# 1064                                 Afghanistan                    Да
# ...

# %%
new_df['Series Name'].unique()
# Out:
# array(['Industry (including construction), value added (% of GDP)',
#        'Agriculture, forestry, and fishing, value added (% of GDP)',
#        'GDP (current US$)', 'GDP growth (annual %)',
#        'Government expenditure on education, total (% of GDP)',
#        'Imports of goods and services (% of GDP)',
#        'Manufacturing, value added (% of GDP)',
#        'Merchandise trade (% of GDP)', 'Military expenditure (% of GDP)',
#        'Research and development expenditure (% of GDP)',
#        'Services, value added (% of GDP)', 'Trade (% of GDP)',
#        'Trade in services (% of GDP)',
#        'Exports of goods and services (% of GDP)',
#        'Domestic general government health expenditure (% of GDP)',
#        'Textiles and clothing (% of value added in manufacturing)',
#        'Other manufacturing (% of value added in manufacturing)',
#        'Machinery and transport equipment (% of value added in manufacturing)',
# ...

# %%
# Оставляю только нужные страны  
new_df = new_df[new_df['Country Name'].isin(['Algeria', 'Ethiopia', 'Namibia', 'South Africa', 'Egypt, Arab Rep.', 'Iran, Islamic Rep.', 'Pakistan', 'Saudi Arabia', 'Turkiye', 'Belarus', 'Moldova', 'Serbia', 'China', 'Mongolia', 'Armenia', 'Azerbaijan', 'Argentina', 'Brazil', 'Mexico', 'Peru', 'Kazakhstan', 'Kyrgyz Republic', 'Tajikistan', 'Turkmenistan', 'Uzbekistan', 'Indonesia', 'Malaysia', 'Philippines', 'Thailand', 'Vietnam', 'India'])]

# %%
new_df = new_df[new_df['Series Name'].isin(['Industry (including construction), value added (% of GDP)',
'GDP (current US$)', 'GDP growth (annual %)',
'Government expenditure on education, total (% of GDP)',
'Manufacturing, value added (% of GDP)',
'Research and development expenditure (% of GDP)',
'Domestic general government health expenditure (% of GDP)',
'Other manufacturing (% of value added in manufacturing)',
'Textiles and clothing (% of value added in manufacturing)',
'Agriculture, forestry, and fishing, value added (% of GDP)',
"Services, value added (% of GDP)", ])]
# Оставляю только нужные признаки
print(len(new_df['Series Name'].unique()))



# Заменяю странные точки на нули : 
new_df = new_df.apply(lambda row: row.replace('..', 0), axis=1)

# Функция для замены запятых в строках на точки (для float):
def f(s):
    s = str(s)
    if s == "..":
        return float(0.0)
    else:
        return float(s.replace(",","."))
    
# Итоговый датафрейм куда будут ссылаться все итоговые колонки: 
itog_df = new_df[['Series Name', 'Region', 'Country Name']]
itog_df = itog_df[itog_df['Country Name'].isin(['Algeria', 'Ethiopia', 'Namibia', 'South Africa', 'Egypt, Arab Rep.', 'Iran, Islamic Rep.', 'Pakistan', 'Saudi Arabia', 'Turkiye', 'Belarus', 'Moldova', 'Serbia', 'China', 'Mongolia', 'Armenia', 'Azerbaijan', 'Argentina', 'Brazil', 'Mexico', 'Peru', 'Kazakhstan', 'Kyrgyz Republic', 'Tajikistan', 'Turkmenistan', 'Uzbekistan', 'Indonesia', 'Malaysia', 'Philippines', 'Thailand', 'Vietnam', 'India'])]
itog_df = itog_df.set_index('Country Name')
# Out:
# 11

# %%
df_Industry = new_df[new_df['Series Name'] == 'Industry (including construction), value added (% of GDP)'].set_index('Country Name')

df_Industry = df_Industry[['2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]', '2021 [YR2021]', '2022 [YR2022]']]
# Оставляю только нужные столбцы

# Применяю функцию
for i in df_Industry:
    df_Industry[i] = df_Industry[i].apply(f)

df_Industry['Сумма'] = df_Industry.apply(lambda row: float(row['2018 [YR2018]']) + 
                           float(row['2019 [YR2019]']) + float(row['2020 [YR2020]']) +
                           float(row['2021 [YR2021]']) + float(row['2022 [YR2022]']), axis=1)
# вычисляю колонку с весом :
itog_df['Industry_sum'] = df_Industry['Сумма']

# %%
df_Agriculture = new_df[new_df['Series Name'] == 'Agriculture, forestry, and fishing, value added (% of GDP)'].set_index('Country Name')

df_Agriculture = df_Agriculture[['2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]', '2021 [YR2021]', '2022 [YR2022]']]
# Оставляю только нужные столбцы

# Применяю функцию
for i in df_Agriculture:
    df_Agriculture[i] = df_Agriculture[i].apply(f)

df_Agriculture['Сумма'] = df_Agriculture.apply(lambda row: float(row['2018 [YR2018]']) + 
                           float(row['2019 [YR2019]']) + float(row['2020 [YR2020]']) +
                           float(row['2021 [YR2021]']) + float(row['2022 [YR2022]']), axis=1)

itog_df['Agriculture_sum'] = df_Agriculture['Сумма']

# %%
df_Manufacture = new_df[new_df['Series Name'] == 'Manufacturing, value added (% of GDP)'].set_index('Country Name')

df_Manufacture = df_Manufacture[['2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]', '2021 [YR2021]', '2022 [YR2022]']]
# Оставляю только нужные столбцы

# Применяю функцию
for i in df_Manufacture:
    df_Manufacture[i] = df_Manufacture[i].apply(f)

df_Manufacture['Сумма'] = df_Manufacture.apply(lambda row: float(row['2018 [YR2018]']) + 
                           float(row['2019 [YR2019]']) + float(row['2020 [YR2020]']) +
                           float(row['2021 [YR2021]']) + float(row['2022 [YR2022]']), axis=1)

itog_df['Manufacture_sum'] = df_Manufacture['Сумма']

# %%
df_Textlines = new_df[new_df['Series Name'] == 'Textiles and clothing (% of value added in manufacturing)'].set_index('Country Name')

df_Textlines = df_Textlines[['2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]', '2021 [YR2021]', '2022 [YR2022]']]
# Оставляю только нужные столбцы

# Применяю функцию
for i in df_Textlines:
    df_Textlines[i] = df_Textlines[i].apply(f)

df_Textlines['Сумма'] = df_Textlines.apply(lambda row: float(row['2018 [YR2018]']) + 
                           float(row['2019 [YR2019]']) + float(row['2020 [YR2020]']) +
                           float(row['2021 [YR2021]']) + float(row['2022 [YR2022]']), axis=1)

itog_df['Textlines_sum'] = df_Textlines['Сумма']

# %%
df_Other_Manufacture = new_df[new_df['Series Name'] == 'Other manufacturing (% of value added in manufacturing)'].set_index('Country Name')

df_Other_Manufacture = df_Other_Manufacture[['2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]', '2021 [YR2021]', '2022 [YR2022]']]
# Оставляю только нужные столбцы

# Применяю функцию
for i in df_Other_Manufacture:
    df_Other_Manufacture[i] = df_Other_Manufacture[i].apply(f)

df_Other_Manufacture['Сумма'] = df_Other_Manufacture.apply(lambda row: float(row['2018 [YR2018]']) + 
                           float(row['2019 [YR2019]']) + float(row['2020 [YR2020]']) +
                           float(row['2021 [YR2021]']) + float(row['2022 [YR2022]']), axis=1)

itog_df['Other_Manufacture_sum'] = df_Other_Manufacture['Сумма']

# %%
df_Government_Health = new_df[new_df['Series Name'] == 'Domestic general government health expenditure (% of GDP)'].set_index('Country Name')

df_Government_Health = df_Government_Health[['2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]', '2021 [YR2021]', '2022 [YR2022]']]
# Оставляю только нужные столбцы

# Применяю функцию
for i in df_Government_Health:
    df_Government_Health[i] = df_Government_Health[i].apply(f)

df_Government_Health['Сумма'] = df_Government_Health.apply(lambda row: float(row['2018 [YR2018]']) + 
                           float(row['2019 [YR2019]']) + float(row['2020 [YR2020]']) +
                           float(row['2021 [YR2021]']) + float(row['2022 [YR2022]']), axis=1)

itog_df['Government_Health_sum'] = df_Government_Health['Сумма']

# %%
df_Research_Develop = new_df[new_df['Series Name'] == 'Research and development expenditure (% of GDP)'].set_index('Country Name')

df_Research_Develop = df_Research_Develop[['2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]', '2021 [YR2021]', '2022 [YR2022]']]
# Оставляю только нужные столбцы

# Применяю функцию
for i in df_Research_Develop:
    df_Research_Develop[i] = df_Research_Develop[i].apply(f)

df_Research_Develop['Сумма'] = df_Research_Develop.apply(lambda row: float(row['2018 [YR2018]']) + 
                           float(row['2019 [YR2019]']) + float(row['2020 [YR2020]']) +
                           float(row['2021 [YR2021]']) + float(row['2022 [YR2022]']), axis=1)

itog_df['Research_Develop_sum'] = df_Research_Develop['Сумма']

# %%
df_Education = new_df[new_df['Series Name'] == 'Government expenditure on education, total (% of GDP)'].set_index('Country Name')

df_Education = df_Education[['2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]', '2021 [YR2021]', '2022 [YR2022]']]
# Оставляю только нужные столбцы

# Применяю функцию
for i in df_Education:
    df_Education[i] = df_Education[i].apply(f)

df_Education['Сумма'] = df_Education.apply(lambda row: float(row['2018 [YR2018]']) + 
                           float(row['2019 [YR2019]']) + float(row['2020 [YR2020]']) +
                           float(row['2021 [YR2021]']) + float(row['2022 [YR2022]']), axis=1)

itog_df['Education_sum'] = df_Education['Сумма']

# %%
df_GDP = new_df[new_df['Series Name'] == 'GDP (current US$)'].set_index('Country Name')

df_GDP = df_GDP[['2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]', '2021 [YR2021]', '2022 [YR2022]']]
# Оставляю только нужные столбцы

# Применяю функцию
for i in df_GDP:
    df_GDP[i] = df_GDP[i].apply(f)

df_GDP['Сумма'] = df_GDP.apply(lambda row: float(row['2018 [YR2018]']) + 
                           float(row['2019 [YR2019]']) + float(row['2020 [YR2020]']) +
                           float(row['2021 [YR2021]']) + float(row['2022 [YR2022]']), axis=1)

itog_df['GDP_sum'] = df_GDP['Сумма']

# %%
df_GDP_Growth = new_df[new_df['Series Name'] == 'GDP growth (annual %)'].set_index('Country Name')

df_GDP_Growth = df_GDP_Growth[['2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]', '2021 [YR2021]', '2022 [YR2022]']]
# Оставляю только нужные столбцы

# Применяю функцию
for i in df_GDP_Growth:
    df_GDP_Growth[i] = df_GDP_Growth[i].apply(f)

df_GDP_Growth['Сумма'] = df_GDP_Growth.apply(lambda row: float(row['2018 [YR2018]']) + 
                           float(row['2019 [YR2019]']) + float(row['2020 [YR2020]']) +
                           float(row['2021 [YR2021]']) + float(row['2022 [YR2022]']), axis=1)

itog_df['GDP_Growth_sum'] = df_GDP_Growth['Сумма']

# %%
df_Services = new_df[new_df['Series Name'] == "Services, value added (% of GDP)"].set_index('Country Name')

df_Services = df_Services[['2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]', '2021 [YR2021]', '2022 [YR2022]']]
# Оставляю только нужные столбцы

# Применяю функцию
for i in df_Services:
    df_Services[i] = df_Services[i].apply(f)

df_Services['Сумма'] = df_Services.apply(lambda row: float(row['2018 [YR2018]']) + 
                           float(row['2019 [YR2019]']) + float(row['2020 [YR2020]']) +
                           float(row['2021 [YR2021]']) + float(row['2022 [YR2022]']), axis=1)

itog_df['Services_sum'] = df_Services['Сумма']

# %%
len(new_df['Series Name'].unique())
# Out:
# 11

# %%
itog_df.drop(['Series Name', 'Region'],axis=1)
# Out:
#               Industry_sum  Agriculture_sum  Manufacture_sum  Textlines_sum  \
# Country Name
# Algeria         189.408573        61.554758        95.658037       0.000000
# Argentina       116.040782        29.560612        72.835392      20.219591
# Armenia         128.747911        58.519580        58.438149      14.611830
# Azerbaijan      247.784813        28.137247        27.149957      14.431214
# Belarus         159.685681        34.877537       111.158578      22.350648
# ...                    ...              ...              ...            ...
# Thailand        171.607169        42.563679       132.087170       6.004849
# Turkiye         147.675635        30.856396       100.742557      64.657432
# Turkmenistan     87.887318        22.079812         0.000000       0.000000
# Uzbekistan      151.716055       123.882052        91.338122      54.301820
# Vietnam         185.824794        61.184070       120.477869      61.604990
#
# ...

# %%
# На каждую уникалькую страну по 8 строк одинаковых, группирую и беру среднее
# сравнивая получившиеся значения с верхней таблицей делаю вывод что значения остаются те же 

itog_df = itog_df.groupby('Country Name').mean()

# %%
itog_df_2 = itog_df.reset_index()

# Сортирую по странам чтоб потом добавлять колонки и что б значения в каждой строке вставали на свои места
itog_df_2 = itog_df_2.sort_values('Country Name')

# itog_df_2 = itog_df_2.sort_values('Industry_sum')
# itog_df_2['index'] = range(1, len(itog_df_2) + 1)
res_df = itog_df_2.copy()

# %%
dict_weight = {'Industry_sum': 1.5, 'Agriculture_sum': 1.5, 'Manufacture_sum': 1.5, 'Textlines_sum': 1.5, 
               'Other_Manufacture_sum': 1.5, 
              'Government_Health_sum': 1, 'Research_Develop_sum': 2, 'Education_sum': 1.5, 'GDP_sum': 1, 
               'GDP_Growth_sum': 2, "Services_sum": 1.5}

itog_df_2 = itog_df_2.sort_values('Industry_sum')
itog_df_2['ind'] = range(1, len(itog_df_2) + 1)
res_df['Industry_sum'] = itog_df_2['ind'] * dict_weight['Industry_sum'] 
itog_df_2 = itog_df_2.drop('ind', axis=1)

itog_df_2 = itog_df_2.sort_values('Agriculture_sum')
itog_df_2['ind'] = range(1, len(itog_df_2) + 1)
res_df['Agriculture_sum'] = itog_df_2['ind'] * dict_weight['Agriculture_sum'] 
itog_df_2 = itog_df_2.drop('ind', axis=1)

itog_df_2 = itog_df_2.sort_values('Manufacture_sum')
itog_df_2['ind'] = range(1, len(itog_df_2) + 1)
res_df['Manufacture_sum'] = itog_df_2['ind'] * dict_weight['Manufacture_sum'] 
itog_df_2 = itog_df_2.drop('ind', axis=1)

itog_df_2 = itog_df_2.sort_values('Textlines_sum')
itog_df_2['ind'] = range(1, len(itog_df_2) + 1)
res_df['Textlines_sum'] = itog_df_2['ind'] * dict_weight['Textlines_sum'] 
itog_df_2 = itog_df_2.drop('ind', axis=1)

itog_df_2 = itog_df_2.sort_values('Other_Manufacture_sum')
itog_df_2['ind'] = range(1, len(itog_df_2) + 1)
res_df['Other_Manufacture_sum'] = itog_df_2['ind'] * dict_weight['Other_Manufacture_sum'] 
itog_df_2 = itog_df_2.drop('ind', axis=1)

itog_df_2 = itog_df_2.sort_values('Government_Health_sum')
itog_df_2['ind'] = range(1, len(itog_df_2) + 1)
res_df['Government_Health_sum'] = itog_df_2['ind'] * dict_weight['Government_Health_sum'] 
itog_df_2 = itog_df_2.drop('ind', axis=1)

itog_df_2 = itog_df_2.sort_values('Research_Develop_sum')
itog_df_2['ind'] = range(1, len(itog_df_2) + 1)
res_df['Research_Develop_sum'] = itog_df_2['ind'] * dict_weight['Research_Develop_sum'] 
itog_df_2 = itog_df_2.drop('ind', axis=1)

itog_df_2 = itog_df_2.sort_values('Education_sum')
itog_df_2['ind'] = range(1, len(itog_df_2) + 1)
res_df['Education_sum'] = itog_df_2['ind'] * dict_weight['Education_sum'] 
itog_df_2 = itog_df_2.drop('ind', axis=1)

itog_df_2 = itog_df_2.sort_values('GDP_sum')
itog_df_2['ind'] = range(1, len(itog_df_2) + 1)
res_df['GDP_sum'] = itog_df_2['ind'] * dict_weight['GDP_sum'] 
itog_df_2 = itog_df_2.drop('ind', axis=1)

itog_df_2 = itog_df_2.sort_values('GDP_Growth_sum')
itog_df_2['ind'] = range(1, len(itog_df_2) + 1)
res_df['GDP_Growth_sum'] = itog_df_2['ind'] * dict_weight['GDP_Growth_sum'] 
itog_df_2 = itog_df_2.drop('ind', axis=1)

itog_df_2 = itog_df_2.sort_values("Services_sum")
itog_df_2['ind'] = range(1, len(itog_df_2) + 1)
res_df["Services_sum"] = itog_df_2['ind'] * dict_weight["Services_sum"] 
itog_df_2 = itog_df_2.drop('ind', axis=1)

res_df['Сумма весов по признакам для каждой страны'] = res_df[['Industry_sum', 'Agriculture_sum', "Services_sum",
                                                                     'Manufacture_sum', 'Textlines_sum', 'Education_sum',
                                                                     'Other_Manufacture_sum', 'Government_Health_sum',
                                                                     'Research_Develop_sum', 'GDP_sum', 'GDP_Growth_sum']].sum(axis=1)
res_df.sort_values('Сумма весов по признакам для каждой страны')[['Country Name', 'Сумма весов по признакам для каждой страны']]


# for col in itog_df_2:
#     if col != 'Country Name':
#         itog_df_2 = itog_df_2.sort_values(col)
    
#         itog_df_2['ind'] = range(1, len(itog_df_2) + 1)
    
#         res_df[col] = itog_df_2['ind'] * dict_weight[col] 
    
#         itog_df_2 = itog_df_2.drop('ind', axis=1)

# res_df.sort_values('Country Name')


# Отсортировать по каждой из колонок в порядке убывания 
# далее порядковый номер каждой страны начиная с 1 умножать на вес признака
# Out:
#           Country Name  Сумма весов по признакам для каждой страны
# 28        Turkmenistan                                        51.0
# 8             Ethiopia                                       159.0
# 18             Namibia                                       194.5
# 3           Azerbaijan                                       213.0
# 25          Tajikistan                                       213.5
# 19            Pakistan                                       223.0
# 0              Algeria                                       230.5
# 20                Peru                                       236.0
# 12          Kazakhstan                                       245.0
# 15              Mexico                                       245.5
# 2              Armenia                                       247.0
# 22        Saudi Arabia                                       257.0
# 16             Moldova                                       257.5
# ...

# %%
# for i in itog_df_2:
#     if i != 'Country Name':
#         itog_df_2 = itog_df_2.sort_values(i) 
        
#         temp_df = itog_df_2.reset_index().sort_values(i)[['Country Name', i, 'index']]
        
#         temp_df[i] = (temp_df['index']+1) * dict_weight[i]
        
#         itog_df_2[i] = temp_df[i]
        
# itog_df_2 = itog_df_2.sort_values('Country Name')
# itog_df_2['Сумма весов по признакам для каждой страны'] = itog_df_2[['Industry_sum', 'Agriculture_sum', 
#                                                                      'Manufacture_sum', 'Textlines_sum',
#                                                                      'Other_Manufacture_sum', 'Government_Health_sum',
#                                                                      'Research_Develop_sum', 'Education_sum']].sum(axis=1)

# %%
# itog_df_2[['Country Name', 'Сумма весов по признакам для каждой страны']].sort_values('Сумма весов по признакам для каждой страны', ascending=False)

# В данном словаре отражено какие веса я дал каким признакам:  

# dict_weight = {'Industry_sum': 2, 'Agriculture_sum': 1, 'Manufacture_sum': 2, 'Textlines_sum': 1.5, 'Other_Manufacture_sum': 1, 
#               'Government_Health_sum': 1.5, 'Research_Develop_sum': 2, 'Education_sum': 1.5}

# %%
# itog_df_2.head(10)
